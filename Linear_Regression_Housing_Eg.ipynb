# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranali-Patil-1212/linear_regression/blob/main/Linear_Regression_Housing_Eg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/All CSV_Files/Housing.csv")

# %%
dataset.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      3
# CHAS       0
# NOX        2
# RM         0
# AGE        1
# DIS        0
# RAD        1
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      1
# MEDV       0
# dtype: int64

# %%
#dataset['INDUS'].isna().sum()
dataset['INDUS'].replace('', np.nan, inplace=True)
dataset['INDUS'].isna().sum()
# Out:
# /tmp/ipython-input-3174359106.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['INDUS'].replace('', np.nan, inplace=True)
# np.int64(3)

# %%
dataset['INDUS'].fillna(dataset['INDUS'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-1999358838.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['INDUS'].fillna(dataset['INDUS'].mean(), inplace=True)

# %%
dataset['INDUS'].isnull().sum()
# Out:
# np.int64(0)

# %%
for col in ['CRIM', 'ZN', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX','LSTAT']:
  dataset[col].replace('', np.nan, inplace=True)
# Out:
# /tmp/ipython-input-1333961216.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[col].replace('', np.nan, inplace=True)

# %%
for col in ['CRIM', 'ZN', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'LSTAT']:
  dataset[col].fillna(dataset[col].mean(), inplace=True)
# Out:
# /tmp/ipython-input-3903921841.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[col].fillna(dataset[col].mean(), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#target

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900  1.0  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671  2.0  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671  2.0  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622  3.0  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622  3.0  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df = pd.DataFrame(dataset)

# %%
target = df.values

# %%
## Independent features and dependent features
X = dataset
y = target

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900  1.0  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671  2.0  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671  2.0  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622  3.0  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622  3.0  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 504  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786  1.0  273
# 505  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875  1.0  273
# 506  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675  1.0  273
# 507  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889  1.0  273
# 508  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050  1.0  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
y
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 3.9690e+02, 4.9800e+00,
#         2.4000e+01],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 3.9690e+02, 9.1400e+00,
#         2.1600e+01],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 3.9283e+02, 4.0300e+00,
#         3.4700e+01],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 5.6400e+00,
#         2.3900e+01],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 3.9345e+02, 6.4800e+00,
#         2.2000e+01],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 7.8800e+00,
#         1.1900e+01]])

# %%
#X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4239342174.py in <cell line: 0>()
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

print(X_train.shape, X_test.shape)
# Out:
# (356, 14) (153, 14)

# %%
regression=LinearRegression()
regression.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-259137199.py in <cell line: 0>()
# ----> 1 regression=LinearRegression()
#       2 regression.fit(X_train, y_train)
#
# NameError: name 'LinearRegression' is not defined

# %%
mse = cross_val_score(regression, X, y, scoring='neg_mean_squared_error', cv=5)

# %%
mse

# %%
np.mean(mse)

# %%
#Prediction
reg_pred = regression.predict(X_test)

# %%
reg_pred

# %%
import seaborn as sns
sns.displot(reg_pred-y_test, kind='kde')

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(reg_pred, y_test)

# %%
score

# %%
from sklearn.metrics import r2_score
print("Train Accuracy:", r2_score(regression.predict(X_train), y_train))
print("Test Accuracy:", r2_score(regression.predict(X_test), y_test))
