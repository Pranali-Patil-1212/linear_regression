# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranali-Patil-1212/linear_regression/blob/main/Advertisment_LinearRegression_BivariateAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sales Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/All CSV_Files/Advertisement (1).csv")

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   2210
# 1   44.5   39.3       45.1   1040
# 2   17.2   45.9       69.3    930
# 3  151.5   41.3       58.5   1850
# 4  180.8   10.8       58.4   1290

# %%
data.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    760
# 196   94.2    4.9        8.1    970
# 197  177.0    9.3        6.4   1280
# 198  283.6   42.0       66.2   2550
# 199  232.1    8.6        8.7   1340

# %%
data.shape
# Out:
# (200, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 6.4 KB

# %%
data.describe()
# Out:
#                TV       radio   newspaper        sales
# count  200.000000  200.000000  200.000000   200.000000
# mean   147.042500   23.264000   30.554000  1402.250000
# std     85.854236   14.846809   21.778621   521.745657
# min      0.700000    0.000000    0.300000   160.000000
# 25%     74.375000    9.975000   12.750000  1037.500000
# 50%    149.750000   22.900000   25.750000  1290.000000
# 75%    218.825000   36.525000   45.100000  1740.000000
# max    296.400000   49.600000  114.000000  2700.000000

# %%
data.describe(include="all")
# Out:
#                TV       radio   newspaper        sales
# count  200.000000  200.000000  200.000000   200.000000
# mean   147.042500   23.264000   30.554000  1402.250000
# std     85.854236   14.846809   21.778621   521.745657
# min      0.700000    0.000000    0.300000   160.000000
# 25%     74.375000    9.975000   12.750000  1037.500000
# 50%    149.750000   22.900000   25.750000  1290.000000
# 75%    218.825000   36.525000   45.100000  1740.000000
# max    296.400000   49.600000  114.000000  2700.000000

# %% [markdown]
# Explore the dataset

# %%
data.nunique()
# Out:
# TV           190
# radio        167
# newspaper    172
# sales        121
# dtype: int64

# %%
data.TV.unique()
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 100.4, 216.4, 182.6, 262.7,
#        198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3, 102.7,
#        131.1,  69. ,  31.5, 139.3, 216.8, 199.1, 109.8,  26.8, 129.4,
#        213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4, 239.8,  75.3,
#         68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 134.3,  28.6, 217.7,
#        250.9, 107.4, 163.3, 197.6, 184.9, 289.7, 135.2, 222.4, 296.4,
#        280.2, 187.9, 238.2, 137.9,  25. ,  90.4,  13.1, 255.4, 225.8,
#        241.7, 175.7, 209.6,  78.2,  75.1, 139.2, 125.7,  19.4, 141.3,
# ...

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [TV, radio, newspaper, sales]
# Index: []

# %% [markdown]
# There is not duplicate row in dataset

# %%
data.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# There is no missing values in dataset

# %%
# Getting the number of columns/variables in dataset
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# Visual Analysis of data

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title("Sale Distribution plot")
sns.distplot(x=data.sales)

plt.subplot(1,2,2)
plt.title("Box Plot for Sale")
sns.boxplot(x=data.sales)
# Out:
# /tmp/ipython-input-2198688862.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.sales)
# <Axes: title={'center': 'Box Plot for Sale'}, xlabel='sales'>

# %%
# Getting Numeric Analysis
data.sales.describe()
# Out:
# count     200.000000
# mean     1402.250000
# std       521.745657
# min       160.000000
# 25%      1037.500000
# 50%      1290.000000
# 75%      1740.000000
# max      2700.000000
# Name: sales, dtype: float64

# %% [markdown]
# Visualising Categorical data

# %%
data.select_dtypes('object').columns
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
plt.figure(figsize=(10,6))

plt.subplot(1,2,1)
plt.title("Box plot for TV")
sns.boxplot(x=data.TV)
# Out:
# <Axes: title={'center': 'Box plot for TV'}, xlabel='TV'>

# %%
plt.subplot(1,2,1)
plt.title("Box plot for radio")
sns.boxplot(x=data.radio)
# Out:
# <Axes: title={'center': 'Box plot for radio'}, xlabel='radio'>

# %%
plt.title("Box plot for newspaper")
sns.boxplot(x=data.newspaper)
# Out:
# <Axes: title={'center': 'Box plot for newspaper'}, xlabel='newspaper'>

# %%
plt.title("Box plot for sales")
sns.boxplot(x=data.sales)
# Out:
# <Axes: title={'center': 'Box plot for sales'}, xlabel='sales'>

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Scatter plot for TVt")
sns.scatterplot(x=data.TV, y=data.sales)

plt.subplot(1,2,2)
plt.title("Scatter Plot for radio")
sns.scatterplot(x=data.radio, y=data.sales)

plt.show()

plt.subplot(1,2,1)
plt.title("Scatter plot for newspaper")
sns.scatterplot(x=data.newspaper, y=data.sales)
# Out:
# <Axes: title={'center': 'Scatter plot for newspaper'}, xlabel='newspaper', ylabel='sales'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title("Scatter plot for TV and radio")
sns.scatterplot(x=data.TV, y=data.radio)

plt.show()

plt.subplot(1,2,1)
plt.title("Scatter Plot for radio and newspaper")
sns.scatterplot(x=data.radio, y=data.newspaper)
plt.show()

plt.subplot(1,2,1)
plt.title("Scatter Plot for TV and newspaper")
sns.scatterplot(x=data.TV, y=data.newspaper)
# Out:
# <Axes: title={'center': 'Scatter Plot for TV and newspaper'}, xlabel='TV', ylabel='newspaper'>

# %%
data.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(data.corr(), annot=True)
plt.title("Correleation map")
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
X=data.drop('sales', axis=1)
y=data['sales']
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# Model building

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score


print("Train Accuracy=", r2_score(lr.predict(X_train), y_train))
print("Test Accuracy=", r2_score(lr.predict(X_test), y_test))
# Out:
# Train Accuracy= 0.8847308591551801
# Test Accuracy= 0.8843196200174289

# %% [markdown]
# The model is good fit
