# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranali-Patil-1212/linear_regression/blob/main/Ice_Cream_Sale_Univariate_analysis_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Predicting the ice cream sale based on temperature

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/All CSV_Files/Ice Cream.csv")

# %%
data.head()
# Out:
#    Temperature  Ice_Cream_Sale
# 0         24.6             535
# 1         26.1             626
# 2         27.8             661
# 3         20.6             488
# 4         11.6             317

# %%
data.tail()
# Out:
#      Temperature  Ice_Cream_Sale
# 495         22.3             525
# 496         32.9             756
# 497         12.6             307
# 498         22.4             567
# 499         29.0             656

# %%
data.shape
# Out:
# (500, 2)

# %%
data.isnull().sum()
# Out:
# Temperature       0
# Ice_Cream_Sale    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(3)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (497, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 497 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature     497 non-null    float64
#  1   Ice_Cream_Sale  497 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 11.6 KB

# %%
data.describe()
# Out:
#        Temperature  Ice_Cream_Sale
# count   497.000000      497.000000
# mean     22.259960      521.563380
# std       8.116756      175.819339
# min       0.000000       10.000000
# 25%      17.100000      406.000000
# 50%      22.400000      529.000000
# 75%      27.800000      643.000000
# max      45.000000     1000.000000

# %%
data.nunique()
# Out:
# Temperature       250
# Ice_Cream_Sale    344
# dtype: int64

# %%
plt.title("Ice Cream Sale Box plot")
sns.boxplot(x=data.Ice_Cream_Sale)
plt.show()

# %%
plt.title("Ice cream sale distribution plot")
sns.distplot(x=data.Ice_Cream_Sale)
plt.show()
# Out:
# /tmp/ipython-input-3549076608.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.Ice_Cream_Sale)

# %%
plt.title("Temperature Distribution plot")
sns.distplot(x=data.Temperature)
plt.show()
# Out:
# /tmp/ipython-input-3270756492.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.Temperature)

# %%
plt.title("Temperature vs Ice Cream Sale")
sns.scatterplot(x=data.Temperature,y=data.Ice_Cream_Sale)
plt.show()

# %%
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
X = data.drop("Ice_Cream_Sale", axis=1)
y = data["Ice_Cream_Sale"]

# %%
X.head()
# Out:
#    Temperature
# 0         24.6
# 1         26.1
# 2         27.8
# 3         20.6
# 4         11.6

# %%
y.head()
# Out:
# 0    535
# 1    626
# 2    661
# 3    488
# 4    317
# Name: Ice_Cream_Sale, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_test.shape, X_train.shape)
# Out:
# (125, 1) (372, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
print("Train Accuracy:", r2_score(lr.predict(X_train), y_train))
print("Test Accuracy:", r2_score(lr.predict(X_test), y_test))
# Out:
# Train Accuracy: 0.9821256084347865
# Test Accuracy: 0.9706907730447029

# %% [markdown]
# Model is good fit
